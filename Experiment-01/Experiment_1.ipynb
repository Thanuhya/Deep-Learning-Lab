# %%
import numpy as np
import matplotlib.pyplot as plt

# XOR input data
X = np.array([
    [0, 0],
    [0, 1],
    [1, 0],
    [1, 1]
])

# XOR output labels
y = np.array([0, 1, 1, 0])

# Create scatter plot
plt.figure(figsize=(6, 6))

# Class 0
plt.scatter(
    X[y == 0][:, 0],
    X[y == 0][:, 1],
    color='royalblue',
    s=180,
    edgecolor='black',
    label='Class 0'
)

# Class 1
plt.scatter(
    X[y == 1][:, 0],
    X[y == 1][:, 1],
    color='tomato',
    marker='^',
    s=180,
    edgecolor='black',
    label='Class 1'
)

# Label each point
labels = ['(0,0)', '(0,1)', '(1,0)', '(1,1)']
for point, label in zip(X, labels):
    plt.text(point[0] + 0.03, point[1] + 0.03, label, fontsize=10)

plt.xlabel("Input Feature x₁")
plt.ylabel("Input Feature x₂")
plt.title("2D Representation of XOR Dataset")
plt.xlim(-0.2, 1.2)
plt.ylim(-0.2, 1.2)
plt.grid(True)
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# XOR data
X = np.array([
    [0, 0],
    [0, 1],
    [1, 0],
    [1, 1]
])

y = np.array([0, 1, 1, 0])

plt.figure(figsize=(6,6))

# Plot Class 0
plt.scatter(X[y==0][:,0], X[y==0][:,1],
            color='royalblue',
            s=180,
            edgecolor='black',
            label='Class 0')

# Plot Class 1
plt.scatter(X[y==1][:,0], X[y==1][:,1],
            color='tomato',
            marker='^',
            s=180,
            edgecolor='black',
            label='Class 1')

# A sample linear decision boundary
x = np.linspace(-0.2, 1.2, 100)
plt.plot(x, x-0.1, 'k--', linewidth=2,
         label='Linear Decision Boundary')

# Labels
labels=['(0,0)','(0,1)','(1,0)','(1,1)']
for point,label in zip(X,labels):
    plt.text(point[0]+0.03, point[1]+0.03, label)

plt.xlim(-0.2,1.2)
plt.ylim(-0.2,1.2)

plt.xlabel("Input Feature x₁")
plt.ylabel("Input Feature x₂")
plt.title("Failure of a Single Linear Decision Boundary for XOR")
plt.grid(True)
plt.legend()

plt.show()

# %%
# Task 8: XOR Classification using TensorFlow

import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

# Ensure reproducible results
np.random.seed(42)
tf.random.set_seed(42)

# XOR Dataset
X = np.array([
    [0, 0],
    [0, 1],
    [1, 0],
    [1, 1]
], dtype=np.float32)

y = np.array([
    [0],
    [1],
    [1],
    [0]
], dtype=np.float32)

# Build the Multi-Layer Perceptron
model = tf.keras.Sequential([
    tf.keras.layers.Input(shape=(2,)),
    tf.keras.layers.Dense(2, activation='sigmoid'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

# Compile the model
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

# Train the model
history = model.fit(
    X,
    y,
    epochs=2000,
    verbose=0
)

# Predictions
predictions = model.predict(X)

print("\nPredictions:\n")

for i in range(len(X)):
    predicted = 1 if predictions[i][0] >= 0.5 else 0
    print(
        f"Input: {X[i]} | "
        f"Expected: {int(y[i][0])} | "
        f"Predicted: {predicted} | "
        f"Probability: {predictions[i][0]:.4f}"
    )
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
#
# Predictions:
#
# Input: [0. 0.] | Expected: 0 | Predicted: 0 | Probability: 0.3281
# Input: [0. 1.] | Expected: 1 | Predicted: 1 | Probability: 0.6370
# Input: [1. 0.] | Expected: 1 | Predicted: 1 | Probability: 0.6495
# Input: [1. 1.] | Expected: 0 | Predicted: 0 | Probability: 0.3970

# %%
# Task 8: XOR Classification using TensorFlow

import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

# Reproducibility
np.random.seed(42)
tf.random.set_seed(42)

# XOR Dataset
X = np.array([
    [0, 0],
    [0, 1],
    [1, 0],
    [1, 1]
], dtype=np.float32)

y = np.array([
    [0],
    [1],
    [1],
    [0]
], dtype=np.float32)

# Build the MLP
model = tf.keras.Sequential([
    tf.keras.layers.Input(shape=(2,)),
    tf.keras.layers.Dense(4, activation='sigmoid'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

# Compile the model
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.05),
    loss='binary_crossentropy',
    metrics=['accuracy']
)

# Train the model
history = model.fit(
    X,
    y,
    epochs=5000,
    verbose=0
)

# Predictions
predictions = model.predict(X, verbose=0)

print("\nPredictions:\n")

for i in range(len(X)):
    predicted = 1 if predictions[i][0] >= 0.5 else 0
    print(
        f"Input: {X[i]} | "
        f"Expected: {int(y[i][0])} | "
        f"Predicted: {predicted} | "
        f"Probability: {predictions[i][0]:.4f}"
    )

# Final Accuracy
loss, accuracy = model.evaluate(X, y, verbose=0)

print("\nFinal Accuracy: {:.2f}%".format(accuracy * 100))
# Out:
# Predictions:
#
# Input: [0. 0.] | Expected: 0 | Predicted: 0 | Probability: 0.0000
# Input: [0. 1.] | Expected: 1 | Predicted: 1 | Probability: 1.0000
# Input: [1. 0.] | Expected: 1 | Predicted: 1 | Probability: 1.0000
# Input: [1. 1.] | Expected: 0 | Predicted: 0 | Probability: 0.0000
#
# Final Accuracy: 100.00%

# %%
# Task 9: Plot Training Loss

import matplotlib.pyplot as plt

plt.figure(figsize=(8,5))

plt.plot(history.history['loss'],
         linewidth=2,
         label='Training Loss')

plt.title("Training Loss vs Epochs")
plt.xlabel("Epoch")
plt.ylabel("Binary Cross Entropy Loss")
plt.grid(True)
plt.legend()

plt.show()

# %%
# Evaluate the trained model
loss, accuracy = model.evaluate(X, y, verbose=0)

print(f"Final Accuracy: {accuracy * 100:.2f}%")
# Out:
# Final Accuracy: 100.00%
